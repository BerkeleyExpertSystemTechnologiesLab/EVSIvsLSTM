# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pickle
import csv

# %%
Sampled_train = pd.read_csv("dataset/train.csv")

# %%
Sampled_train
# Out:
#         faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 0               0.0            1.0       1  0.25038   3674.0   4529.0
# 1               0.0            1.0       2  0.25109   3659.4   4556.6
# 2               0.0            1.0       3  0.25038   3660.3   4477.8
# 3               0.0            1.0       4  0.24977   3661.3   4512.1
# 4               0.0            1.0       5  0.29405   3679.0   4497.0
# ...             ...            ...     ...      ...      ...      ...
# 270395         20.0           24.0     496  0.28437   3645.3   4476.8
# 270396         20.0           24.0     497  0.27925   3687.0   4471.1
# 270397         20.0           24.0     498  0.27898   3671.8   4453.8
# 270398         20.0           24.0     499  0.26937   3691.9   4495.6
# 270399         20.0           24.0     500  0.26889   3680.8   4487.4
#
#         xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# ...

# %%
sample = Sampled_train[['faultNumber', 'xmv_10', 'xmv_4', 'xmv_11', 'xmeas_30', 'xmeas_25']]

# %%
sample.to_csv('data.csv')
